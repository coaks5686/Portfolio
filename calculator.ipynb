# %%
import math

while True:

    print("Calculator Menu")
    print("----------------")
    print("1. Add")
    print("2. Subtract")
    print("3. Multiply")
    print("4. Divide")
    print("5. Square")
    print("6. Square Root")
    print("7. Exit")
    print("----------------")
    choice = input("Type one of the following options:")
    if choice == "1":
        num1 = float(input("Enter First Number:"))
        num2 = float(input("Enter Second Number:"))
        result = num1+num2
        print(result)
    elif choice == "2":
        num1 = float(input("Enter First Number:"))
        num2 = float(input("Enter Second Number:"))
        result = num1-num2
        print(result)
    elif choice == "3":
        num1 = float(input("Enter First Number:"))
        num2 = float(input("Enter Second Number:"))
        result = num1*num2
        print(result)
    elif choice == "4":
        num1 = float(input("Enter First Number:"))
        num2 = float(input("Enter Second Number:"))
        result = num1/num2
        print(result)
    elif choice == "5":
        num1 = float(input("Enter Number:"))
        result = num1**2
        print(result)
    elif choice == "6":
        num1 = float(input("Enter Number:"))
        result = math.sqrt(num1)
        print(result)
    elif choice == "7":
        print("Exiting Program")
        break
# Out:
# Calculator Menu
# ----------------
# 1. Add
# 2. Subtract
# 3. Multiply
# 4. Divide
# 5. Square
# 6. Square Root
# 7. Exit
# ----------------
# 360.0
# Calculator Menu
# ----------------
# 1. Add
# 2. Subtract
# 3. Multiply
# 4. Divide
# 5. Square
# 6. Square Root
# 7. Exit
# ----------------
# Exiting Program
