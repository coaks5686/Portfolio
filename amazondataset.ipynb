# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import pyspark as ps
from pathlib import Path
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder

# %%
downloads = Path.home() / "Downloads" 
csv_path = Path(downloads) / "amazon.csv"
print(csv_path)
print(csv_path.exists())
# Out:
# C:\Users\Owner\Downloads\amazon.csv
# True

# %%
df = pd.read_csv(csv_path)
df.head(10)
# Out:
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3  B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4  B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
# 5  B08Y1TFSP6  pTron Solero TB301 3A Type-C Data and Fast Cha...
# 6  B08WRWPM22  boAt Micro USB 55 Tangle-free, Sturdy Micro US...
# 7  B08DDRGWTJ             MI Usb Type-C Cable Smartphone (Black)
# 8  B008IFXQFU  TP-Link USB WiFi Adapter for PC(TL-WN725N), N1...
# 9  B082LZGK39  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
#
#                                             category discounted_price  \
# 0  Computers&Accessories|Accessories&Peripherals|...             ₹399
# 1  Computers&Accessories|Accessories&Peripherals|...             ₹199
# ...

# %%
df.columns = df.columns.str.strip()

# %%
for column in df.columns:
    print(repr(column))
# Out:
# 'product_id'
# 'product_name'
# 'category'
# 'discounted_price'
# 'actual_price'
# 'discount_percentage'
# 'rating'
# 'rating_count'
# 'about_product'
# 'user_id'
# 'user_name'
# 'review_id'
# 'review_title'
# 'review_content'
# 'img_link'
# 'product_link'

# %%
# The values are in text form and not in number format. We need to convert them to number format.
#total_sales = df['discounted_price'].sum()
#print(f"Total sales: {total_sales}")

# %%
df['discounted_price'] = df['discounted_price'].str.replace('₹', '').str.replace(',', '').astype(float)
df.dtypes
# Out:
# product_id              object
# product_name            object
# category                object
# discounted_price       float64
# actual_price            object
# discount_percentage     object
# rating                  object
# rating_count            object
# about_product           object
# user_id                 object
# user_name               object
# review_id               object
# review_title            object
# review_content          object
# img_link                object
# product_link            object
# dtype: object

# %%
total_discounted_sales = df['discounted_price'].sum()
print(f"'Total Sales:' {total_discounted_sales}")
# Out:
# 'Total Sales:' 4578580.43

# %%
df['actual_price'] = df['actual_price'].str.replace('₹', '').str.replace(',', '').astype(float)
total_sales_for_actual = df['actual_price'].sum()
print(f'Total Sales if sold at original price {total_sales_for_actual}')
# Out:
# Total Sales if sold at original price 7976911.28

# %%
money_lost = total_sales_for_actual - total_discounted_sales
money_lost = round(money_lost, 2)
print(f"₹{money_lost} is the difference between the amount we would have made on regular price versus discounted")
# Out:
# ₹3398330.85 is the difference between the amount we would have made on regular price versus discounted
