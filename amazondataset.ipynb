# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import pyspark as ps
from pathlib import Path
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder

# %%
downloads = Path.home() / "Downloads" 
csv_path = Path(downloads) / "Sales-Export_2019-2020.csv"
print(csv_path)
print(csv_path.exists())
# Out:
# C:\Users\Owner\Downloads\Sales-Export_2019-2020.csv
# True

# %%
df = pd.read_csv(csv_path)
df.head(5)
# Out:
#     country  order_value_EUR       cost         date  category  \
# 0    Sweden         17,524.02   14122.61   2/12/2020     Books
# 1   Finland        116,563.40   92807.78   9/26/2019     Games
# 2  Portugal        296,465.56  257480.34   7/11/2019  Clothing
# 3  Portugal         74,532.02   59752.32    4/2/2020    Beauty
# 4     Spain        178,763.42  146621.76  12/22/2019     Games
#
#        customer_name    sales_manager           sales_rep device_type  \
# 0    Goldner-Dibbert     Maxie Marrow       Madelon Bront      Mobile
# 1   Hilll-Vandervort       Hube Corey         Wat Bowkley      Mobile
# 2     Larkin-Collier  Celine Tumasian  Smitty Culverhouse          PC
# 3  Hessel-Stiedemann  Celine Tumasian        Aurelie Wren          PC
# 4     Johns and Sons     Emalia Dinse     Bertha Walbrook      Tablet
#
#      order_id
# 0  70-0511466
# 1  28-6585323
# 2  58-7703341
# 3  14-6700183
# 4  15-8765160

# %%
df.columns = df.columns.str.strip()

# %%
for column in df.columns:
    print(repr(column))
# Out:
# 'country'
# 'order_value_EUR'
# 'cost'
# 'date'
# 'category'
# 'customer_name'
# 'sales_manager'
# 'sales_rep'
# 'device_type'
# 'order_id'

# %%
df['order_value_EUR'] = df["order_value_EUR"].str.replace(',', '')

# %%
print(df["order_value_EUR"].dtype)
print(df["order_value_EUR"].head())
# Out:
# object
# 0     17524.02
# 1    116563.40
# 2    296465.56
# 3     74532.02
# 4    178763.42
# Name: order_value_EUR, dtype: object

# %%
print(type(df))
print(df.columns)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index(['country', 'order_value_EUR', 'cost', 'date', 'category',
#        'customer_name', 'sales_manager', 'sales_rep', 'device_type',
#        'order_id'],
#       dtype='object')

# %%
print(df["order_value_EUR"].head(10))
# Out:
# 0     17524.02
# 1    116563.40
# 2    296465.56
# 3     74532.02
# 4    178763.42
# 5     84900.24
# 6     71620.08
# 7    156585.22
# 8     78461.13
# 9     64827.80
# Name: order_value_EUR, dtype: object

# %%
df['order_value_EUR'] = pd.to_numeric(df['order_value_EUR'], errors='coerce')

# %%
# the numbers in order to do the math and predict
y = df['order_value_EUR']
y.head(5)
# Out:
# 0     17524.02
# 1    116563.40
# 2    296465.56
# 3     74532.02
# 4    178763.42
# Name: order_value_EUR, dtype: float64

# %%
#These are the clues for the model.
X = df[["country", "category", "device_type"]]

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42
)

# %%
encoder() = OneHotEncoder
# Out:
#   Cell In[195], line 1
#     encoder() = OneHotEncoder
#     ^
# SyntaxError: cannot assign to function call here. Maybe you meant '==' instead of '='?

# %%
x_train_encoded = encoder.fit_transform(X_train)
